# %%
# This notebook demonstrates how to generate keyword counts using our keyword list 
# Install NLTK and pandas
# !pip install nltk pandas

# %%
import nltk
# Download NLTK components
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\018850882\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\018850882\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\018850882\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\018850882\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# ...

# %%
# import necessary objects for lemmatization
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
from nltk import sent_tokenize, word_tokenize
# Create a lemmatize instance
wnl = WordNetLemmatizer()
# important pandas
import pandas as pd

# %%
# Keep keywords in a dictionary
wl_dict = {'Compensation and Benefits': {'high-performing', 'absence', 'sale_commission', 'post-retirement', 'restricted_stock_unit', 'tax-deferred_basis', 'equity-based', 'paycheck', 'salary', 'pay', 'educational_assistance', 'flextime', 'spouse', 'health_saving', 'incentive_award', 'equity_grant', 'company-matched', 'stock-based_compensation_award', 'commission', 'restricted_stock', 'adoption_assistance', 'restrict_stock', 'compensate_fairly', 'saving_account', 'cash-based_compensation_award', 'vision_coverage', 'caregiver', 'stock-based_compensation', 'retiree', 'vested', 'salary_reduction', 'stock-based_award', 'equity-based_compensation_award', 'maternity_leave', 'paid-time-off', 'education_reimbursement', 'company-paid', 'pay_parental_leave', 'co-pays', 'employer-sponsored', 'ltip', 'vest', 'long-term_disability_insurance', 'generous_pay_time', 'parenting', 'bonus_payment', 'competitive_compensation_package', 'tuition_reimbursement', 'smoke_cessation', 'vest_condition', 'minimum_wage', 'valuable_fringe', 'wage', 'dependent_care_flexible_spending', 'company-provided', 'bereavement', 'market-competitive_compensation', 'stipend', 'company-paid_benefit', 'short-term_incentive', 'variable_pay', 'stock_option_grant', 'hourly_wage', 'tax-advantaged', 'performance-based_bonus', 'childcare', 'high_performer', 'performance-based', 'matching_contribution', 'cost-sharing', 'equity-based_incentive', 'cash_bonus', 'broad-based_equity', 'physical_therapy', 'family-friendly', 'flexible_work_schedule', 'long_term_disability', 'child_care', 'benefit_package', 'vacation_time', 'insurance_coverage', 'jury', 'healthcare', 'equity_ownership', 'cash-based_performance_bonus', 'annual_cash', 'life_insurance', 'cash-based', 'discretionary_bonus', 'autism', 'bonus_award', 'pet_insurance', 'pay_time', 'dental', 'family_member', 'remuneration', 'stock_award', 'employee_stock_purchase', 'incentive_compensation', 'total_reward_package', 'assistance_program', 'relief_fund', 'insurance', 'loved_one', 'paternal', 'esop', 'surrogacy_assistance', 'commuter_benefit', 'family_care', 'base_wage', 'perk', 'cash_incentive_plan', 'long-term_incentive', 'paid_leave', 'new_parent', 'sick_leave', 'commission-based', 'broad-based_stock_incentive', 'disability_insurance', 'sick_time', 'market-competitive_salary', 'equity-based_grant', 'dependent', 'critical_illness', 'reimbursement', 'holiday', 'education_assistance', 'severance', 'industry_peer', 'prescription_drug', 'competitive_salary', 'equity-based_award', 'confidential_counseling', 'incentive_bonus', 'pay_parental', 'competitive_compensation', 'retirement_saving_plan', 'retirement_benefit', 'pension_plan', 'incentivize', 'pay_vacation', 'pay-for-performance', 'broad-based_stock_grant', 'paid-time', 'defined_benefit', 'bereavement_leave', 'financial_assistance', 'compensation', 'variable_compensation', 'flexible_time-off', 'retirement_plan', 'total_compensation_package', 'health_care', 'pto', 'broad-based_equity_award', 'fitness_reimbursement', 'military_leave', 'parental_leave', 'annual_bonus', 'competitive_base_salary', 'immediate_family', 'incentive_plan', 'hourly_basis', 'family_leave', 'unpaid_leave', 'stock_grant', 'caregiving', 'benefits', 'overtime', 'salaries', 'defined_contribution', 'paternity', 'income_protection', 'unpaid_leaf', 'competitive_wage', 'profit-sharing', 'compensation_philosophy', 'employer-paid', 'time-off', 'incentivizing', 'dental_insurance', 'deferred_compensation', 'sabbatical', 'define_contribution', 'short-term_disability', 'flexible_spending', 'daycare', 'profit_sharing', 'medical_insurance', 'pay-for-performance_philosophy', 'equity_award', 'stock_purchase_plan', 'hospital_indemnity', 'reward_package', 'share-based_compensation', 'incentivized', 'elder_care', 'payroll_deduction', 'compensation_package', 'tuition_reimbursement_program', 'welfare_benefit', 'comprehensive_benefit_package', 'prescription_drug_benefit', 'company-subsidized', 'cash_incentive', 'vision_insurance', 'tuition', 'benefit', 'stock-based', 'competitive_benefit_package', 'market-competitive_pay', 'long-term_disability', 'student_loan', 'parental_leave_policy', 'total_reward', 'rsus', 'identity_theft', 'flexible_spending_account', 'caregiver_leave', 'disability_coverage', 'incentive-based', 'retirement_saving', 'share-based', 'stock_ownership_plan', 'supplemental_life', 'complimentary', 'care_provider', 'identity_theft_insurance', 'parental', 'espp', 'restrict_stock_unit', 'performance-driven', 'eto', 'accident_insurance', 'performance-based_cash', 'eldercare', 'financial_well-being', 'save_plan', 'payroll', 'merit-based', 'equity-based_compensation', 'stock_ownership', 'perquisite', 'competitive_pay', 'retirement_planning', 'match_contribution', 'pay_time-off', 'vacation', 'dismemberment', 'spending_account', 'employment_package', 'stock_option', 'hourly_rate', 'vesting', 'financial_hardship', 'medical_coverage', 'tuition_assistance', 'incentive', 'fair_wage', 'sick_day', 'employer_match', 'scholarship', 'hsa', 'parent', 'saving_plan', 'juneteenth', 'annual_incentive', '401k', 'maternal', 'ksop', 'paid_time', 'employer_contribution', 'base_salary', 'retirement', 'top_performer', 'pay_holiday', 'bonus', 'assistance_fund', 'maternity', 'market_median', 'child-care', 'pension', 'incentivizes'}, 'Demographics and others': {'stem-related', 'stagger_shift', 'vocational', 'qualified_personnel', 'demographic', 'non-management', 'work_schedule', 'per_hour', 'job_function', 'motivated', 'highly_skilled', 'independent_contractor', 'high_caliber', 'management-level', 'high_potential', 'average_tenure', 'vacancy', 'name_executive_officer', 'bachelor', 'contract_employee', 'full-time', 'non-employee', 'contractor', 'executive_officer', 'senior_leadership_team', 'skilled', 'sale_force', 'qualified_individual', 'people', 'highly_educate', 'non-union', 'highly_qualify', 'senior_leader', 'assistant_manager', 'high_performing', 'staffed', 'contract_worker', 'unskilled_labor', 'master_degree', 'labor_market', 'full_time', 'pre-employment', 'senior_leadership', 'participation_rate', 'independent_consultant', 'front-office', 'technician', 'non-represented', 'temporary_worker', 'senior_manager', 'salesperson', 'human_capital', 'executive_leadership', 'sale_representative', 'work-related', 'professional', 'workforce_demographic', 'staff_member', 'highly_qualified', 'back-office', 'hour_per_week', 'recent_graduate', 'part-time', 'hourly_team_member', 'senior_management_team', 'college_graduate', 'senior-level', 'talent', 'employ_approximately', 'non-executive', 'mid-level_manager', 'shift_schedule', 'independent_agent', 'labor_force', 'headcount', 'part-time_basis', 'crew', 'teammates', 'highly-skilled', 'talented_individual', 'electrical_worker', 'employee', 'management_trainee', 'workload', 'full-time_equivalent', 'contingent_worker', 'full-time_basis', 'crewmembers', 'human_capital_management', 'senior_management', 'part_time', 'highly-qualified', 'crewmember', 'fixed-term', 'engineer', 'outside_consultant', 'subcontractor', 'crew_member', 'associate', 'staffing_level', 'teammate', 'personally', 'unskilled', 'salaried', 'technicians', 'college_student', 'frontline', 'administrator', 'front-line', 'well-qualified', 'employ', 'co-op', 'non-salaried', 'doctorate', 'full_time_equivalent', 'demographics', 'entire_workforce', 'fulltime', 'human-capital', 'consultant', 'well-trained', 'team_member', 'qualified', 'human_resource', 'long-tenured', 'entry-level', 'workforce', 'workday', 'agent', 'general_manager', 'workweek', 'district_manager', 'laborer', 'hourly', 'graduate_degree', 'apprentice', 'skill', 'highly_talented', 'employee-related', 'highly_trained', 'personnel', 'worker', 'high-caliber', 'entry_level', 'qualified_applicant', 'per_week', 'senior_executive', 'manager', 'advanced_degree', 'employed', 'fte', 'labor_cost', 'staffing', 'executive-level', 'seniority', 'manager-level', 'clerk', 'staff', 'hris', 'unemployment'}, 'Diversity, Equity, and Inclusion (DEI)': {'different_perspective', 'affirmative_action', 'pregnancy', 'protected_characteristic', 'anti-racism', 'latinx', 'gender_expression', 'ethnically', 'equitably', 'crgs', 'racial_injustice', 'pay_gap', 'veterans', 'unconscious_bias_training', 'transgender', 'cultural_background', 'equal_treatment', 'anti-retaliation', 'identity', 'unbiased', 'self-identifies', 'disability_equality_index', 'living_wage', 'social_justice', 'bully', 'ethnic_diversity', 'equality', 'black', 'diverse_background', 'african-american', 'equal_pay', 'racial_equity', 'unique_perspective', 'generational', 'indigenous', 'racially', 'woman', 'eeoc', 'racial_equality', 'alaskan_native', 'reasonable_accommodation', 'affirmative_action_plan', 'non-caucasian', 'self-identified', 'self-disclosed', 'military_veteran', 'marital_status', 'people_of_color', 'gender', 'racism', 'dei', 'lesbian', 'non-discrimination', 'retaliation', 'pay_parity', 'ethnic', 'protected_class', 'nondiscrimination', 'intimidation', 'deib', 'age', 'equal_employment', 'non-minorities', 'poc', 'disability', 'belonging', 'human_right_campaign', 'multicultural', 'injustice', 'underprivileged', 'underserved_community', 'sexual_harassment', 'underrepresented_population', 'female', 'underrepresented_minority', 'gender_identity', 'employment_opportunity', 'inclusion', 'men', 'ethnic_origin', 'disabled', 'lgbtqia', 'retribution', 'protect_veteran_status', 'individuality', 'nondiscriminatory', 'anti-harassment', 'asian_american', 'pay_equity', 'religious', 'unlawful_discrimination', 'equal_opportunity', 'diverse_slate', 'racial_justice', 'diverse_candidate', 'native_american', 'women', 'nationality', 'discriminatory_harassment', 'historically_underrepresented', 'socio-economic_status', 'minority_group', 'creed', 'minority', 'veteran_status', 'racially_diverse', 'brgs', 'diverse_candidate_slate', 'lgbtq_equality', 'values-based', 'under-represented_minority', 'pacific_islander', 'diverse', 'socioeconomic', 'socio-economic', 'latino', 'asian-american', 'marginalize', 'bipoc', 'inclusivity', 'naacp', 'diverse_perspective', 'multi-cultural', 'self-expression', 'inclusion-focused', 'ergs', 'political_affiliation', 'varied_perspective', 'bias-free', 'racial', 'urms', 'self-identify', 'gender-equality', 'underrepresented_group', 'inclusive_workplace', 'domestic_partner', 'gender_identification', 'religious_belief', 'alaska_native', 'equal_opportunity_employer', 'equally', 'inclusion-related', 'cdo', 'non-white', 'inclusiveness', 'male', 'cross-cultural', 'neurodiversity', 'ethnicity', 'diversity', 'caucasian', 'fairness', 'race', 'underrepresented_community', 'status_protect', 'respectfully', 'stereotype', 'equal_employment_opportunity', 'heritage', 'lgbt+', 'without_bias', 'disparity', 'corporate_equality_index', 'gender-neutral', 'descent', 'american_indian', 'ethnic_group', 'traditionally_underrepresented', 'discrimination', 'bisexual', 'non-minority', 'urm', 'discriminatory', 'bullying', 'hispanic-serving', 'religion', 'diversity-focused', 'diversity-related', 'self-identifying', 'harassment', 'multigenerational', 'multiracial', 'justice', 'bias', 'african_american', 'equitable_treatment', 'military_status', 'inclusive', 'gay', 'different_background', 'ancestry', 'diverse_pool', 'islander', 'underrepresented', 'racial_minority', 'underrepresented_ethnic', 'gender_parity', 'treat_fairly', 'human_right', 'background', 'systemic_racism', 'unique_background', 'ethnic_minority', 'protect_veteran', 'eeo', 'dei_council', 'inclusively', 'ide', 'equal-opportunity', 'courtesy', 'historically_black_college', 'anti-discrimination', 'ethnic_background', 'marital', 'under-represented', 'equality_index', 'veteran-owned', 'allyship', 'resource_group', 'under-represented_group', 'inequity', 'edi', 'gei', 'sexual', 'harassment_prevention', 'national_origin', 'ethnically_diverse', 'respectful_workplace', 'implicit_bias', 'lgbtq+', 'hawaiian', 'eigs', 'native_hawaiian', 'affinity_group', 'non-discriminatory', 'underrepresentation', 'social_injustice', 'inequality', 'unconscious_bias', 'empathy', 'sexual_orientation', 'dib', 'sex', 'representation', 'veteran', 'prejudice', 'hispanic', 'lgbtq', 'respectful_conduct', 'equitable', 'discriminate', 'listening_session', 'self-identification'}, 'Health and Safety (COVID)': {'remote_working', 'work_remotely', 'teleworking', 'daily_temperature_check', 'temperature-taking', 'wear_face_covering', 'reopening', 'pandemic', 'remote_work_environment', 'remote-working', 'test_positive', 'remote_work_arrangement', 'international_non-essential_travel', 'social_distancing', 'telecommuting', 'travel_restriction', 'temperature_screening', 'self-screening', 'face-masks', 'non-essential_travel', 'physical_distance', 'self-quarantine', 'remote-work', 'novel_coronavirus', 'cdc_guideline', 'remote_work', 'shelter-in-place', 'vaccine', 'work-from-home_policy', 'work-at-home', 'covid-19', 'virus', 'proper_social_distancing', 'face_covering', 'social_distance', 'essential_worker', 'vaccination', 'cdc', 'face_cover', 'vaccinate', 'covid', 'stay-at-home', 'temperature_check', 'coronavirus_disease', 'temperature_screen', 'work-from-home_arrangement', 'quarantining', 'virus_exposure', 'covid-related', 'social-distancing', 'stay-at-home_order', 'wear_mask', 'mask_wearing', 'self-health', 'mask-wearing', 'mask', 'social_distancing_guideline', 'work-from-home', 'quarantine', 'respirator', 'face_mask', 'coronavirus', 'quarantined', 'facemasks', 'masking', 'pandemic-related', 'working-from-home', 'telecommute', 'physical_distancing', 'mask_requirement'}, 'Health and Safety (General)': {'public_health', 'hazardous', 'enhance_cleaning', 'hygiene_practice', 'life-saving', 'mental', 'workplace_injury', 'first_responder', 'incident-free', 'death', 'osha_total_recordable', 'precautionary_measure', 'health_authority', 'hand_sanitizer', 'biometric_screening', 'flu_shot', 'sanitizing', 'mental_health', 'fatality', 'accident', 'physically_safe', 'fitness', 'oshas', 'occupational', 'safety_protocol', 'protection_equipment', 'healthful', 'dart', 'working_condition', 'safety', 'hse', 'mental_well-being', 'recordable_incident_rate', 'fitness_center', 'cleaning_supply', 'work-related_fatality', 'case_rate', 'occupational_health', 'recordable_injury', 'recordable_injury_rate', 'illness', 'near-misses', 'injury_per', 'sanitizing_procedure', 'zero_accident', 'incident_per', 'protective_equipment', 'frequent_cleaning', 'ergonomic', 'prevent_injury', 'msha', 'lost_time', 'occupational_safety', 'ltcr', 'serious_injury', 'first_aid', 'enhanced_cleaning', 'incidence', 'flu_vaccination', 'handwashing', 'fitness_class', 'bls', 'health-related', 'zero_incident', 'safety-focused', 'unsafe', 'hazard', 'sanitation_procedure', 'behavioral_health', 'healthy_workplace', 'harm', 'unsafe_condition', 'safety-first', 'osha', 'recordable_incident', 'healthy_lifestyle', 'lost-time', 'vpp', 'ventilation', 'aes', 'safely', 'protective_gear', 'near-miss', 'public_health_authority', 'well-being', 'cleaning_procedure', 'lost-time_incident', 'wellness', 'injury', 'healthy', 'sanitizer', 'accidental_death', 'lifestyle', 'medical_condition', 'incident', 'ohi', 'provide_personal_protective', 'hand_sanitize_station', 'injury_rate', 'occupational_injury', 'preventative_measure', 'lose_workday', 'safer', 'ppe', 'emotional', 'incident_rate', 'depression', 'health_screening', 'hazardous_material', 'sanitization', 'physically', 'labor_statistic', 'health', 'lti', 'acc', 'emergency_response', 'ergonomics', 'trir', 'mentally', 'occupational_illness', 'emotional_well-being', 'disinfect', 'tir', 'welfare', 'mental_disability', 'lose_time_incident_rate', 'cleaning_protocol', 'disinfection', 'osha_recordable', 'safety-related', 'clean_supply', 'sanitation', 'workspace', 'hygiene', 'injury-free', 'ltir', 'sif', 'personal_protective_equipment', 'total_recordable_incident_rate', 'safe', 'incidence_rate', 'sanitize', 'disinfecting', 'healthy_living', 'rir', 'infectious_disease', 'accidental', 'qhse', 'ohsas', 'zero-incident', 'employee-hours', 'zero_injury', 'lose_time', 'safe_working', 'disinfectant', 'work-related_injury', 'sanitizers'}, 'Labor relations and culture': {'townhall', 'representative_body', 'professional_development', 'education', 'train', 'significant_work_stoppage', 'internship', 'anonymous', 'talent_acquisition', 'attrition', 'union_contract', 'recruitment', 'courage', 'orientation', 'whistleblower', 'interviewing', 'work-life', 'forced_labor', 'collegial', 'fundraise', 'engagement_survey', 'grievance', 'questionnaire', 'career-enhancing', 'uaw', 'absenteeism', 'talent_mobility', 'layoff', 'engaging', 'charitable_foundation', 'succession_planning_process', 'ethical_conduct', 'corrupt', 'town_hall_meeting', 'worker_council', 'community_involvement', 'candidate_pool', 'post-employment', 'skillset', 'non-profit_organization', 'retaining', 'elearning', 'job_satisfaction', 'empathetic', 'townhalls', 'fraud', 'fundraising', 'supervisor', 'job_duty', 'employee-led_group', 'talent_pool', 'family', 'child_labor', 'tutoring', 'new_hire', 'candor', 'continuous_learn', 'dependent_care', 'laundering', 'open_communication', 'values-based_culture', 'emotional_intelligence', 'job_description', 'mid-career', 'work_environment', 'employment-related_work_stoppage', 'tenet', 'motivate', 'results-driven', 'united_way', 'cultivate', 'learning', 'skills-based', 'one-on-one', 'co-worker', 'recruit', 'self-paced_learning', 'compliance_hotline', 'career_mobility', 'anonymous_survey', 'open_position', 'tutor', 'hire', 'attraction', 'volunteer', 'moral', 'interviewer', 'enjoyable_workplace', 'abuse', 'labor_relation', 'workplace', 'employee-driven', 'commute', 'attracting', 'career_advancement', 'professionally', 'charitable_cause', 'voluntary_attrition', 'volunteer_activity', 'opeiu', 'international_brotherhood', 'charitable_organization', 'team-based', 'ethic', 'cohort', 'succession', 'charity', 'self-directed_learning', 'empowerment', 'continual_learning', 'retain_qualified', 'reductions-in-force', 'voluntary_attrition_rate', 'impasse', 'collective_bargaining_arrangement', 'cultural_fit', 'iuoe', 'pulse_survey', 'at-will', 'newly_hire', 'trained', 'attract', 'onboarding', 'core_principle', 'on-board', 'empowered', 'counseling', 'anti-corruption', 'pafca', 'fast-paced', 'coworkers', 'high-performance_culture', 'labor_disruption', 'employee_value_proposition', 'honestly', 'inappropriate_behavior', 'anonymously', 'counselling', 'eap', 'training', 'core_value', 'employment_decision', 'charitable_give', 'team-oriented', 'collective_bargaining_unit', 'renegotiation', 'labor_law', 'early-career', 'cwa', 'customized_corporate_training', 'continuous_learning', 'motto', 'on-boarding', 'humility', 'performance_appraisal', 'engagement', 'attracts', 'soft_skill', 'ethic_hotline', 'job_fair', 'job-specific', 'turnover', 'interview', 'collegiality', 'umwa', 'anti-bribery', 'bargain_unit', 'vto', 'personality', 'potential_successor', 'counseling_session', 'collaborative', 'rotational_assignment', 'lay-offs', 'charitable_donation', 'unionization', 'labor-related_work_stoppage', 'interview_panel', 'ibew', 'voluntary_turnover_rate', 'volunteer_hour', 'termination', 'external_hire', 'furlough', 'exit_interview', 'bribery', 'ethical', 'afl-cio', 'resignation', 'attrition_rate', 'mentorships', 'top_talent', 'turnover_rate', 'involuntary_turnover', 'whistleblower_policy', 'open-door_policy', 'reduction-in-force', 'skillsets', 'union', 'recruiting', 'succession_planning', 'cross-training', 'career_growth', 'collaboration', 'chro', 'decency', 'retain_top', 'team-building', 'employee-centric', 'job_opening', 'early_career', 'self-development', 'candid_feedback', 'trainee', 'skill-building', 'work_stoppage', 'advancement', 'highly_collaborative', 'people-centric', 'unionized', 'hiring', 'on-the-job_training', 'ethics', 'leadership', 'upskilling', 'job_assignment', 'tenure', 'philosophy', 'competency-based', 'job-related', 'ibt', 'employee-led', 'labour', 'on-the-job', 'volunteering', 'humble', 'voluntary_turnover', 'applicant', 'executive-sponsored', 'retain_talented', 'unethical_behavior', 'succession_plan', 'slavery', 'best_employer', 'self-assessment', 'international_union', 'community_outreach', 'bargaining_group', 'performance_evaluation', 'organized_labor', 'high_ethical_standard', 'meritocracy', 'people-first', 'code_of_conduct', 'ethically', 'retain', 'career_path', 'virtual_classroom', 'talent_attraction', 'survey', 'solicit_feedback', 'disaster_relief', 'charitable_contribution', 'human_trafficking', 'direct_report', 'work-life_balance', 'internal_promotion', 'retains', 'collective_bargaining_agreement', 'ilo', 'voluntary_separation', 'ethicsline', 'cultural', 'professionalism', 'fairly_compensate', 'tenured', 'fair_treatment', 'mentorship', 'emerge_leader', 'unethical', 'career_development', 'reskilling', 'recruiter', 'retention_rate', 'mentor', 'mentoring', 'credential', 'learning_management_system', 'charitable_gift', 'career', 'collective_bargaining', 'career_progression', 'career-oriented', 'nonprofit_organization', 'anonymous_hotline', 'cultural_awareness', 'employee-friendly', 'virtual_town_hall', 'bargaining_unit', 'trainer', 'promote-from-within', 'confidentially', 'like-minded', 'talent_pipeline', 'honest', 'uwua', 'confidential_reporting', 'evaluation_process', 'internal_candidate', 'employer_brand', 'material_work_stoppage', 'internal_mobility', 'top-performing', 'furloughed', 'anticorruption', 'non-unionized', 'new-hire', 'skill-based', 'alpa', 'coaching', 'integrity', 'working_environment', 'review_process', 'flexible_schedule', 'employment-related', 'iam', 'reward', 'on-demand_learning', 'online_learning', 'inspiring', 'unionize', 'promotion', 'retentive', 'commitment', 'retention', 'reskill', 'upskill', 'attendance_policy', 'corporate_philanthropy', 'inspirational', 'hiring_practice', 'charitable_matching', 'anonymous_feedback', 'corruption', 'consultation', 'on-the-job_learning', 'collective-bargaining_agreement', 'compassion', 'abusive', 'confidential_hotline', 'trade_union', 'engagement_score', 'candidate_slate', 'onboarding_process', 'culture', 'open_dialogue', 'courageous', 'colleague', 'labor-related', 'employee-focused', 'whistleblower_hotline', 'reprisal'}}
# Get phrases from the keywords (i.e., those joined with "_")
ngrams = [w for wl in wl_dict.values() for w in wl if "_" in w]

# %%
# Define a function to tokenize a doc into sentences and lemmatize them
# Return a list of tokenized sentences, where each sentence is a list of lemmatized tokens
def get_tokenized_lemmatized_sents(text):
    # Define a function to lemmatize tokens
    def lemm_tokens_nltk(tokenized_sents):
        # Get the part of speech of a word
        def get_wordnet_pos(treebank_tag):
            if treebank_tag.startswith('J'):
                return wordnet.ADJ
            elif treebank_tag.startswith('V'):
                return wordnet.VERB
            elif treebank_tag.startswith('N'):
                return wordnet.NOUN
            elif treebank_tag.startswith('R'):
                return wordnet.ADV
            else:
                return wordnet.NOUN
    
        tokenized_lemm_sents = []
        for tokenized_sent in tokenized_sents:
            word_pos = pos_tag(tokenized_sent)
            lemm_words = [wnl.lemmatize(sw[0], get_wordnet_pos(sw[1])) for sw in word_pos]
            tokenized_lemm_sents.append(lemm_words)
        return tokenized_lemm_sents
    
    sents = sent_tokenize(text)
    tokenized_sents = [word_tokenize(s) for s in sents]
    # To lower cases so that proper nouns are handled properly
    tokenized_sents = [[t.lower() for t in s] for s in tokenized_sents] 
    lemm_sents = lemm_tokens_nltk(tokenized_sents)
    return lemm_sents

# %%
# Define a function to join words that are phrases in the keyword list, e.g., converting "human resource" into "human_resource"
# Take a list of sentences, where each sentence is a list of tokens
def join_phrases(tokenzied_sents):
    sents_str = [" ".join(sent) for sent in tokenzied_sents]
    text = "\n".join(sents_str)
    text = " " + text + " "
    re_ngrams = [" " + a.replace("_", " ") + " " for a in ngrams] # e.g. " human resource "
    ngrams_underline = [" "  + a + " " for a in ngrams] # e.g. " human_resource "
    pattern_zip = zip(re_ngrams, ngrams_underline)
    for p in pattern_zip:
        text = text.replace(p[0], p[1]) # e.g., replace "human resource" with "human_resource"
    sents = text.split("\n")
    sents = [s.split(" ") for s in sents]
    return sents

# %%
# Define a function to tokenize the text, lemmatize the tokens, and join words into phrases
# Return a list of sentences, where each sentence is a list of tokens that have been lemmatized and phrased
def get_sent_tokens_phrased(text):
    lemm_sents = get_tokenized_lemmatized_sents(text)
    # Join phrases
    lemm_ngram_sents = join_phrases(lemm_sents)
    return lemm_ngram_sents

# %%
# Define a function to get keyword counts from tokenized sentences
# Take a list of tokenized sentences, where each sentence is a list of tokens that have been lemmatized and phrased
# Return a dictionary, where the key is an HC topic and the value is the keyword count of that topic
def get_keyword_counts(tokenized_sents):
    def flatten_list_of_lists(l):
        flat_list = [item for sublist in l for item in sublist]
        return flat_list
    all_tokens = flatten_list_of_lists(tokenized_sents)
    wc_dict = {c: 0 for c in wl_dict.keys()}
    for c, wl in wl_dict.items():
        for t in all_tokens:
            if t in wl:
                wc_dict[c] += 1
                # print(t)
    wc_dict["Total"] = sum(wc_dict.values())
    return wc_dict

# %%
# A list of two sample HC disclosures
docs = [
    "The sustainability of Abbotts business depends on attracting, engaging and developing talented people with diverse backgrounds who share Abbotts mission to help people live their healthiest possible lives. Abbott provides its employees opportunities to grow and develop their careers, market competitive compensation and benefit programs, and the satisfaction of being part of a global company dedicated to improving health in more than 160 countries. As of December 31, 2020, Abbott employed approximately 109,000 people, 70% of whom were employed outside of the U.S. Women represented 47% of Abbotts U.S. workforce, 45% of its global workforce, and 39% of its managers.The health, safety and wellness of its employees is an Abbott priority embedded at every level of its business.  Abbotts integrated Environmental, Health and Safety organization governs health, safety and wellness at Abbotts facilities. Abbott also maintains global policies and standards for managing employee health and safety. Abbott takes a holistic approach to employee well-being. Abbotts global wellness programs are designed to meet the unique needs of employees across businesses and geographies and offer a wide range of programs, including supporting the mental, financial and physical health of employees and their families. For example, for over 20 years, Abbott has annually offered Exercise Across Abbott, which is a four-week physical wellness program that encourages employees to team up with colleagues and track how many minutes they exercise each day. Over 22,000 Abbott employees across 72 countries took part in 2020. During the COVID-19 pandemic, Abbott has taken aggressive steps to limit exposure and enhance the safety of facilities for its employees, including implementing mandatory temperature screening and social distancing, providing and requiring the use of personal protective equipment, and at most U.S. facilities, onsite COVID-19 testing. Abbott has an integrated global talent management process that is designed to identify and assess talent across the organization and provide equal and consistent opportunities for employees to develop their skills. All levels of employees participate in Abbotts annual performance management process to create development plans that support their particular career objectives, and Abbott provides a broad range of training, mentoring and other development opportunities to help its employees meet these objectives. The board of directors conducts an annual Talent Management Review, focusing on development of talent, diversity, and succession planning for critical positions. Similar reviews take place at every level of Abbott to develop talent and diversity across the organization. Abbott is committed to developing a workplace that is inclusive for all. Abbott ties executive compensation to human capital management, including diversity outcomes, to sustain an inclusive culture and the fair and balanced treatment of Abbotts employees. Abbotts employee networks play an important role in building an inclusive culture across all Abbott operations.  A member of Abbotts senior management serves as a sponsor for each of these networks, helping to align their objectives with Abbotts business strategies. Abbott has ten such networks, which are: Advancing Professionals Network (supporting early career employees), Asian Leadership and Cultural Network, Black Business Network, Flex Network (employees with part-time and flexible schedules), LA VOICE Network (supporting Hispanic and Latino employees), People with Disabilities Network, PRIDE (supporting LGBTQ employees), Veterans Network, Women Leaders of Abbott, and Women in STEM. Abbott offers professional development programs, which provide recent college graduates the opportunity to rotate through different areas of Abbott, often with the chance to work outside their home country. In 2020, 52% of the participants were women. Also, Abbott hosts hundreds of college students for paid internships. In 2020, 55% of the U.S. interns were women and 39% were minorities. Further, Abbott has operated a STEM internship program for high school students in the U.S. since 2012. The programs objective is to increase the number of students pursuing STEM-related careers and contribute to a more diverse talent pipeline for Abbott. In 2020, 58% of the STEM interns were women and 71% were minorities. Abbott is committed to building, retaining, and motivating a diverse talent pipeline that can meet the current and future needs of its businesses. To that end, Abbott provides market competitive compensation, healthcare benefits, pension and/or retirement savings plans, and several programs to facilitate employees building an ownership stake in Abbott, including a global long-term incentive program for employees generally beginning at the manager level. Abbott also has procedures and processes focused on providing employees equitable compensation, regardless of race or gender or other personal characteristics.",
    "We have a global and varied workforce, with major employee centers in the U.S., Canada, U.K. and Romania. As of the end of 2020, we employed approximately 17,000 employees within our business globally with approximately 10,000 within our North America segment and 7,000 within our Europe segment. Of the 17,000 employees, approximately 660 of our employees are in our Global Business Centers based in Milwaukee, Wisconsin and Bucharest, Romania. As of the end of 2020, approximately 33% and 29% of our North America and Europe workforces, respectively, are represented by trade unions or councils, which are subject to collective bargaining agreements, which come due for renegotiation from time to time. The Company strives to be a provider of meaningful experiences for its employees and a safe and healthy workplace for all employees. We believe that building a strong and diverse workforce is a significant contributor to our success as a business and to deliver on our purpose, and that we value and respect our differences. We believe that diversity with inclusion is the key to collaboration and a winning team culture. A significant component of the revitalization plan announced in October 2019 was the launch of a refreshed purpose (uniting people to celebrate all life’s moments), ambition (first choice for our people, consumers and customers) and shared company values (the first of which is Putting People First), all designed with a purpose of shifting the culture of the organization to drive stronger employee engagement and business engagement. With the overarching goals described in the preceding paragraph as guides, the leadership team and the chief people and diversity officers for the North America and Europe business units are tasked with managing all employment-related matters including recruitment, retention, leadership and development, compensation planning, succession planning, performance management, and diversity and inclusion. The Compensation Human Resource Committee of the Board of Directors is responsible for establishing and reviewing the overall compensation philosophy of the Company and providing oversight on certain human capital matters, including the Company’s talent retention and development, leadership development, talent pipeline, programs and systems for performance management and diversity and inclusion initiatives. The Audit Committee oversees the Company’s risk management program to identify and mitigate potential risks, including human capital issues. The Board of Directors then receives regular reports and recommendations from management and the board committees to help guide the Company’s strategy on retaining and developing a diverse and talented workforce. In North America, we promote and maintain employee resource groups for a number of different communities in our employee population - by race/ethnicity, by gender, LGBTQ+, early professionals, young families, and veterans, amongst others. We encourage participation in these groups as we believe it provides an open forum for individual employees who may share similar concerns or experiences. We also promote and emphasize leadership and development opportunities for our employees which includes our First Choice Learning Center, in-person and online training programs, and experiential training opportunities to encourage and promote employee health and safety, assist in building core competencies, learning best practices and developing leadership capabilities. As we work to a more diverse workforce and management team, the Company has developed programs to encourage the recruitment, retention and training of diverse leaders and working to ensure we have a highly skilled and diverse workforce. We track and monitor our progress on metrics of gender and race, particularly in the U.S., though data on race is not tracked in all jurisdictions. We aim to ensure that our employees have a healthy and safe work environment. Our supply chain has adopted and implemented a framework we call world class supply chain 2.0 at many of our brewery and other locations. As part of that framework, the Company's environment, health and safety policy guides the Company’s efforts in maintaining safe and healthy workplaces where we take a proactive approach to the identification and control of environment, health and safety risks. We work to improve our Environment, Health and Safety (EHS) performance through methodologies that aim to prevent workplace injuries and illness, and reduce environmental impacts of our operations. Our safety focus was evident during our response to the coronavirus pandemic where we implemented additional health and safety measures in the breweries and our distribution centers, ensuring these federally designated essential operations could continue to operate and we could protect our employees. We enhanced our cleaning protocols at the majority of our facilities including enhanced sanitization, social distancing, temperature screenings, cloth facemasks and hand sanitizers, instituted a paid leave coronavirus policy and program, adopted a voluntary unpaid leave program, and expanded access to virtual healthcare, remote fitness and wellness support and to our employee assistance program."
    ]

# %%
# Generate a master dataframe to store the variables of all documents
df = pd.DataFrame()
# Loop through each doc, generate the variables, store them in a dataframe, and append the dataframe to the master dataframe
for i, doc in enumerate(docs):
    sents = get_sent_tokens_phrased(doc)
    kw_counts = get_keyword_counts(sents)
    kw_counts["DocID"] = i
    df0 = pd.DataFrame(kw_counts, index=[i])
    df = pd.concat([df, df0])
# Rearrange the column names so that the DOC ID comes first
cols = [df.columns.to_list()[-1]] + df.columns.to_list()[:-1]
df = df[cols]
# Display the dataframe, which has only two rows for this illustration
df
# Out:
#    DocID  Compensation and Benefits  Demographics and others  \
# 0      0                         11                       43
# 1      1                          7                       32
#
#    Diversity, Equity, and Inclusion (DEI)  Health and Safety (COVID)  \
# 0                                      26                          5
# 1                                      19                          6
#
#    Health and Safety (General)  Labor relations and culture  Total
# 0                           19                           23    127
# 1                           24                           28    116
